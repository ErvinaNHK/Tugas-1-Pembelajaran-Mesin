# %% [markdown]
# <a href="https://colab.research.google.com/github/ErvinaNHK/Tugas-1-Pembelajaran-Mesin/blob/main/Tugas_1_Data_Population_Indonesia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = '/content/indonesia_population.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#     Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0   2020   273523615             1.07        2898047          -98955
# 1   2019   270625568             1.10        2955025          -98955
# 2   2018   267670543             1.14        3019580          -98955
# 3   2017   264650963             1.18        3094582          -98955
# 4   2016   261556381             1.23        3173125          -98955
# 5   2015   258383256             1.33        3309808          -90889
# 6   2010   241834215             1.34        3108949         -266737
# 7   2005   226289470             1.36        2955129         -229931
# 8   2000   211513823             1.44        2915913          -13534
# 9   1995   196934260             1.66        3104172           -7082
# 10  1990   181413402             1.92        3286190           52256
# 11  1985   164982451             2.27        3506923           95016
# 12  1980   147447836             2.44        3353422           75749
# ...

# %%
data.head()
# Out:
#    Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0  2020   273523615             1.07        2898047          -98955
# 1  2019   270625568             1.10        2955025          -98955
# 2  2018   267670543             1.14        3019580          -98955
# 3  2017   264650963             1.18        3094582          -98955
# 4  2016   261556381             1.23        3173125          -98955
#
#    Median Age  Fertility Rate  Density (P/Km²)  Urban Pop %  Urban Population  \
# 0        29.7            2.32              151         56.4         154188546
# 1        28.8            2.42              149         55.8         150900390
# 2        28.8            2.42              148         55.1         147603006
# 3        28.8            2.42              146         54.5         144294861
# 4        28.8            2.42              144         53.9         140972925
#
#    Country's Share of World Pop  World Population  Indonesia Global Rank
# ...

# %%
print(data.dtypes)
# Out:
# Year                              int64
# Population                        int64
# Yearly % Change                 float64
# Yearly Change                     int64
# Migrants (net)                    int64
# Median Age                      float64
# Fertility Rate                  float64
# Density (P/Km²)                   int64
# Urban Pop %                     float64
# Urban Population                  int64
# Country's Share of World Pop    float64
# World Population                  int64
# Indonesia Global Rank             int64
# dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#     Year  Population  Yearly % Change  Yearly Change  Median Age  \
# 0   2020   273523615             1.07        2898047        29.7
# 1   2019   270625568             1.10        2955025        28.8
# 2   2018   267670543             1.14        3019580        28.8
# 3   2017   264650963             1.18        3094582        28.8
# 4   2016   261556381             1.23        3173125        28.8
# 5   2015   258383256             1.33        3309808        28.5
# 6   2010   241834215             1.34        3108949        27.2
# 7   2005   226289470             1.36        2955129        25.6
# 8   2000   211513823             1.44        2915913        24.4
# 9   1995   196934260             1.66        3104172        22.8
# 10  1990   181413402             1.92        3286190        21.3
# 11  1985   164982451             2.27        3506923        19.9
# 12  1980   147447836             2.44        3353422        19.1
# ...

# %%
data.describe()
# Out:
#               Year    Population  Yearly % Change  Yearly Change  \
# count    18.000000  1.800000e+01        18.000000   1.800000e+01
# mean   1994.166667  1.931995e+08         1.792222   2.939353e+06
# std      22.350813  6.949752e+07         0.627165   4.725715e+05
# min    1955.000000  7.727342e+07         1.070000   1.546022e+06
# 25%    1976.250000  1.348725e+08         1.255000   2.907896e+06
# 50%    1997.500000  2.042240e+08         1.550000   3.057081e+06
# 75%    2015.750000  2.607631e+08         2.397500   3.176414e+06
# max    2020.000000  2.735236e+08         2.740000   3.506923e+06
#
#        Migrants (net)  Median Age  Fertility Rate  Density (P/Km²)  \
# count       18.000000   18.000000       18.000000        18.000000
# mean    -23377.111111   23.933333        3.601111       106.555556
# std     116859.633392    4.306630        1.388253        38.417555
# min    -266737.000000   18.500000        2.320000        43.000000
# ...

# %%
data.loc[:,"Population":].corr()
# Out:
#                               Population  Yearly % Change  Yearly Change  \
# Population                      1.000000        -0.936109       0.544167
# Yearly % Change                -0.936109         1.000000      -0.259705
# Yearly Change                   0.544167        -0.259705       1.000000
# Migrants (net)                 -0.804463         0.843445      -0.230283
# Median Age                      0.933010        -0.958204       0.229224
# Fertility Rate                 -0.964731         0.959029      -0.490911
# Density (P/Km²)                 0.999971        -0.937358       0.542675
# Urban Pop %                     0.990682        -0.962650       0.434147
# Urban Population                0.981134        -0.953208       0.393152
# Country's Share of World Pop    0.927832        -0.789628       0.790484
# World Population                0.999714        -0.939484       0.527494
# Indonesia Global Rank          -0.830987         0.700280      -0.816671
#
# ...

# %%
# @title Population vs Year

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Population', y='Year', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Dengan API
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-ab4b6280-27ad-40f7-ae68-8516cbb72fee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab4b6280-27ad-40f7-ae68-8516cbb72fee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "Population Indonesia"
# Out:
# ...
# ref                                                              title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# iamsouravbanerjee/world-population-dataset                       World Population Dataset                            16KB  2022-10-20 17:51:07          45390        605  1.0
# anandhuh/population-indonasia                                    Population of Indonesia (2050-1955)                  3KB  2022-05-01 11:33:14            923         67  0.9117647
# whenamancodes/world-population-live-dataset                      World Population Live Dataset 2022                  10KB  2022-09-10 11:29:21           6515         88  1.0
# ...

# %%
# !kaggle datasets download iamsouravbanerjee/world-population-dataset
# Out:
# ...
#   0% 0.00/15.7k [00:00<?, ?B/s]
# 100% 15.7k/15.7k [00:00<00:00, 25.6MB/s]

# %%
# !unzip /content/world-population-dataset.zip
# Out:
# Archive:  /content/world-population-dataset.zip
#   inflating: world_population.csv

# %%
pd.read_csv('world_population.csv')
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...
